# %%
from tensorflow import keras
import pandas as pd
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential

RUN_NAME = 'run 2 with 5 nodes'

training_data_df = pd.read_csv("sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# Define the model
model = Sequential()
model.add(Dense(5, input_dim=9, activation='relu', name='layer_1'))
model.add(Dense(100, activation='relu', name='layer_2'))
model.add(Dense(50, activation='relu', name='layer_3'))
model.add(Dense(1, activation='linear', name='output_layer'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Create a TensorBoard logger
logger = keras.callbacks.TensorBoard(
    log_dir='logs/{}'.format(RUN_NAME),
    write_graph=True,
    histogram_freq=5
)

# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2,
    callbacks=[logger]
)

# Load the separate test data set
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))
# Out:
# 2022-02-10 21:28:15.797164: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2022-02-10 21:28:15.797188: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2022-02-10 21:28:15.797243: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# Epoch 1/50
# 32/32 - 0s - loss: 0.0442
# Epoch 2/50
# 32/32 - 0s - loss: 0.0197
# Epoch 3/50
# 32/32 - 0s - loss: 0.0137
# Epoch 4/50
# 32/32 - 0s - loss: 0.0084
# Epoch 5/50
# 32/32 - 0s - loss: 0.0049
# Epoch 6/50
# 32/32 - 0s - loss: 0.0035
# Epoch 7/50
# 32/32 - 0s - loss: 0.0026
# Epoch 8/50
# 32/32 - 0s - loss: 0.0023
# 2022-02-10 21:28:16.049224: I tensorflow/core/profiler/lib/profiler_session.cc:136] Profiler session initializing.
# 2022-02-10 21:28:16.049240: I tensorflow/core/profiler/lib/profiler_session.cc:155] Profiler session started.
# 2022-02-10 21:28:16.066528: I tensorflow/core/profiler/lib/profiler_session.cc:71] Profiler session collecting data.
# 2022-02-10 21:28:16.067116: I tensorflow/core/profiler/lib/profiler_session.cc:172] Profiler session tear down.
# 2022-02-10 21:28:16.067990: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/run 2 with 5 nodes/train/plugins/profile/2022_02_10_21_28_16
# 2022-02-10 21:28:16.068457: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for trace.json.gz to logs/run 2 with 5 nodes/train/plugins/profile/2022_02_10_21_28_16/Abigails-MBP-2.trace.json.gz
# 2022-02-10 21:28:16.069415: I tensorflow/core/profiler/rpc/client/save_profile.cc:137] Creating directory: logs/run 2 with 5 nodes/train/plugins/profile/2022_02_10_21_28_16
# 2022-02-10 21:28:16.069803: I tensorflow/core/profiler/rpc/client/save_profile.cc:143] Dumped gzipped tool data for memory_profile.json.gz to logs/run 2 with 5 nodes/train/plugins/profile/2022_02_10_21_28_16/Abigails-MBP-2.memory_profile.json.gz
# 2022-02-10 21:28:16.070887: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/run 2 with 5 nodes/train/plugins/profile/2022_02_10_21_28_16Dumped tool data for xplane.pb to logs/run 2 with 5 nodes/train/plugins/profile/2022_02_10_21_28_16/Abigails-MBP-2.xplane.pb
# Dumped tool data for overview_page.pb to logs/run 2 with 5 nodes/train/plugins/profile/2022_02_10_21_28_16/Abigails-MBP-2.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/run 2 with 5 nodes/train/plugins/profile/2022_02_10_21_28_16/Abigails-MBP-2.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/run 2 with 5 nodes/train/plugins/profile/2022_02_10_21_28_16/Abigails-MBP-2.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/run 2 with 5 nodes/train/plugins/profile/2022_02_10_21_28_16/Abigails-MBP-2.kernel_stats.pb
# Epoch 9/50
# 32/32 - 0s - loss: 0.0019
# Epoch 10/50
# 32/32 - 0s - loss: 0.0016
# Epoch 11/50
# 32/32 - 0s - loss: 0.0014
# Epoch 12/50
# 32/32 - 0s - loss: 0.0011
# Epoch 13/50
# 32/32 - 0s - loss: 0.0011
# Epoch 14/50
# 32/32 - 0s - loss: 8.5242e-04
# Epoch 15/50
# 32/32 - 0s - loss: 7.5622e-04
# Epoch 16/50
# 32/32 - 0s - loss: 7.4054e-04
# Epoch 17/50
# 32/32 - 0s - loss: 6.0114e-04
# Epoch 18/50
# 32/32 - 0s - loss: 5.4325e-04
# Epoch 19/50
# 32/32 - 0s - loss: 4.9975e-04
# Epoch 20/50
# 32/32 - 0s - loss: 4.2767e-04
# Epoch 21/50
# 32/32 - 0s - loss: 3.8117e-04
# Epoch 22/50
# 32/32 - 0s - loss: 3.8426e-04
# Epoch 23/50
# 32/32 - 0s - loss: 3.4658e-04
# Epoch 24/50
# 32/32 - 0s - loss: 3.3913e-04
# Epoch 25/50
# 32/32 - 0s - loss: 3.3532e-04
# Epoch 26/50
# 32/32 - 0s - loss: 2.7694e-04
# Epoch 27/50
# 32/32 - 0s - loss: 2.7047e-04
# Epoch 28/50
# 32/32 - 0s - loss: 2.4910e-04
# Epoch 29/50
# 32/32 - 0s - loss: 2.5918e-04
# Epoch 30/50
# 32/32 - 0s - loss: 2.2771e-04
# Epoch 31/50
# 32/32 - 0s - loss: 2.1455e-04
# Epoch 32/50
# 32/32 - 0s - loss: 2.4803e-04
# Epoch 33/50
# 32/32 - 0s - loss: 2.1952e-04
# Epoch 34/50
# 32/32 - 0s - loss: 1.8643e-04
# Epoch 35/50
# 32/32 - 0s - loss: 1.7622e-04
# Epoch 36/50
# 32/32 - 0s - loss: 1.8875e-04
# Epoch 37/50
# 32/32 - 0s - loss: 1.8304e-04
# Epoch 38/50
# 32/32 - 0s - loss: 1.8877e-04
# Epoch 39/50
# 32/32 - 0s - loss: 1.5406e-04
# Epoch 40/50
# 32/32 - 0s - loss: 1.6725e-04
# Epoch 41/50
# 32/32 - 0s - loss: 1.5372e-04
# Epoch 42/50
# 32/32 - 0s - loss: 1.5049e-04
# Epoch 43/50
# 32/32 - 0s - loss: 1.4834e-04
# Epoch 44/50
# 32/32 - 0s - loss: 1.3935e-04
# Epoch 45/50
# 32/32 - 0s - loss: 1.4097e-04
# Epoch 46/50
# 32/32 - 0s - loss: 1.3585e-04
# Epoch 47/50
# 32/32 - 0s - loss: 1.3765e-04
# Epoch 48/50
# 32/32 - 0s - loss: 1.5956e-04
# Epoch 49/50
# 32/32 - 0s - loss: 1.3811e-04
# Epoch 50/50
# 32/32 - 0s - loss: 1.2878e-04
# The mean squared error (MSE) for the test data set is: 0.0002267465606564656
